# %% [markdown]
# ## Impotation des Packages Necessaire

# %%
from bs4 import BeautifulSoup
import requests
import csv

# %%
url= 'https://immobilier-au-senegal.com/list-layout/page/2/'

# %%
## Recupere le code source de la page a Scapper
c_source=requests.get(url).text

# %%
soup= BeautifulSoup(c_source, 'lxml')
# print(soup.prettify())

# %%
article= soup.find('article', class_="rh_list_card")
print(article.prettify())
# Out:
# <article class="rh_list_card">
#  <div class="rh_list_card__wrap">
#   <figure class="rh_list_card__thumbnail">
#    <div class="rh_figure_property_list_one">
#     <a href="https://immobilier-au-senegal.com/bien/terrains-de-600-metres-carres-a-vendre-a-saly-senegal-4/">
#      <div class="post_thumbnail" style="background: url('https://immobilier-au-senegal.com/wp-content/uploads/2025/11/Terrains-600m2-a-Saly-02-488x326.jpeg') 50% 50% no-repeat; background-size: cover;">
#      </div>
#      <!-- /.post_thumbnail -->
#     </a>
#     <div class="rh_overlay">
#     </div>
#     <div class="rh_overlay__contents rh_overlay__fadeIn-bottom">
#      <a href="https://immobilier-au-senegal.com/bien/terrains-de-600-metres-carres-a-vendre-a-saly-senegal-4/">
#       Voir le bien
#      </a>
#     </div>
#     <!-- /.rh_overlay__contents -->
#    </div>
#    <div class="rh_list_card__btns">
#     <span class="favorite-btn-wrap favorite-btn-19748">
#      <span class="favorite-placeholder highlight__red hide user_not_logged_in" data-propertyid="19748" data-tooltip="Ajouté aux favoris">
#       <svg height="24" viewbox="0 0 24 21" width="24" xmlns="http://www.w3.org/2000/svg">
#        <path class="rh_svg" d="M1089.48,1923.98a6.746,6.746,0,0,1,9.54,9.54L1089,1943l-10.02-9.48a6.746,6.746,0,0,1,9.54-9.54A0.641,0.641,0,0,0,1089.48,1923.98Z" transform="translate(-1077 -1922)">
#        </path>
#       </svg>
#      </span>
#      <a class="favorite add-to-favorite user_not_logged_in" data-propertyid="19748" data-tooltip="Ajouter aux favoris" href="#">
#       <svg height="24" viewbox="0 0 24 21" width="24" xmlns="http://www.w3.org/2000/svg">
#        <path class="rh_svg" d="M1089.48,1923.98a6.746,6.746,0,0,1,9.54,9.54L1089,1943l-10.02-9.48a6.746,6.746,0,0,1,9.54-9.54A0.641,0.641,0,0,0,1089.48,1923.98Z" transform="translate(-1077 -1922)">
#        </path>
#       </svg>
#      </a>
#     </span>
#     <span class="add-to-compare-span compare-btn-19748" data-property-id="19748" data-property-image="https://immobilier-au-senegal.com/wp-content/uploads/2025/11/Terrains-600m2-a-Saly-02-488x326.jpeg" data-property-title="Terrains de 600 mètres carrés à vendre à Saly Sénégal" data-property-url="https://immobilier-au-senegal.com/bien/terrains-de-600-metres-carres-a-vendre-a-saly-senegal-4/">
#      <span class="compare-placeholder highlight hide" data-tooltip="Ajouté pour comparer">
#       <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#        <path d="M1144,1942l-8,1v3l-7-5,7-5v3l8,1A1,1,0,0,1,1144,1942Zm-22-14,8,1v3l7-5-7-5v3l-8,1A1,1,0,0,0,1122,1928Z" transform="translate(-1121 -1922)">
#        </path>
#       </svg>
#      </span>
#      <a class="rh_trigger_compare add-to-compare" data-tooltip="Ajouter" href="https://immobilier-au-senegal.com/bien/terrains-de-600-metres-carres-a-vendre-a-saly-senegal-4/">
#       <svg height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#        <path d="M1144,1942l-8,1v3l-7-5,7-5v3l8,1A1,1,0,0,1,1144,1942Zm-22-14,8,1v3l7-5-7-5v3l-8,1A1,1,0,0,0,1122,1928Z" transform="translate(-1121 -1922)">
#        </path>
#       </svg>
#      </a>
#     </span>
#    </div>
#    <!-- /.rh_list_card__btns -->
#   </figure>
#   <!-- /.rh_list_card__thumbnail -->
#   <div class="rh_list_card__details_wrap">
#    <div class="rh_list_card__details">
#     <h3>
#      <a href="https://immobilier-au-senegal.com/bien/terrains-de-600-metres-carres-a-vendre-a-saly-senegal-4/">
#       Terrains de 600 mètres carrés à vendre à Saly Sénégal
#      </a>
#     </h3>
#     <p class="rh_list_card__excerpt">
#      2 terrains jumelés de 600…
#     </p>
#     <!-- /.rh_list_card__excerpt -->
#     <div class="rh_list_card__meta_wrap">
#     </div>
#     <!-- /.rh_list_card__meta_wrap -->
#    </div>
#    <!-- /.rh_list_card__details -->
#    <div class="rh_list_card__priceLabel">
#     <div class="rh_list_card__price">
#      <span class="status">
#       À vendre
#      </span>
#      <!-- /.rh_prop_card__type -->
#      <p class="price">
#       32.000.000Fr par parcelle
#      </p>
#      <!-- /.price -->
#     </div>
#     <!-- /.rh_list_card__price -->
#    </div>
#    <!-- /.rh_list_card__priceLabel -->
#   </div>
#   <!-- /.rh_list_card__details_wrap -->
#  </div>
#  <!-- /.rh_list_card__wrap -->
# </article>

# %%
## recuperation du Titre du premier article 
headline= article.h3.a.text
print(headline)
# Out:
# Terrains de 600 mètres carrés à vendre à Saly Sénégal

# %%
## recuperation du Commentaire du premier article 
summarry= article.find('div', class_="rh_list_card__details_wrap").p.text
print(summarry)
# Out:
# 2 terrains jumelés de 600…

# %%
## recuperation du Status du premier article 
## Status veut dire si le terrain est en vente , en location ou c un terrain que l'on veut acheter
status= article.find('div', class_="rh_list_card__price").span.text
print(status)
# Out:
# 						À vendre

# %%
# ## recuperation du Prix du premier article 
price= article.find('div', class_="rh_list_card__price").p.text
print(price)
# Out:
# 						 32.000.000Fr par parcelle

# %% [markdown]
# ## Maintenant on va recuperer tous les Articles avec les differents champs ennonce ci-dessous

# %%
csv_file= open('page1_IAS_scrape.csv', 'w', encoding='utf-8')
csv_writer= csv.writer(csv_file)
csv_writer.writerow(['headline','summarry','status','price'])
# Out:
# 32

# %%
for article in soup.find_all('article', class_="rh_list_card"):
    headline= article.h3.a.text
    print(headline)
    summarry= article.find('div', class_="rh_list_card__details_wrap").p.text
    print(summarry)
    status= article.find('div', class_="rh_list_card__price").span.text
    print(status)
    price= article.find('div', class_="rh_list_card__price").p.text
    print(price)

    print()

    csv_writer.writerow([headline, summarry, status, price])
csv_file.close()
# Out:
# Terrains de 600 mètres carrés à vendre à Saly Sénégal
# 2 terrains jumelés de 600…
#
# 						À vendre
#
# 						 32.000.000Fr par parcelle
#
# Terrain de 300 mètres carrés à vendre à Saly Sénégal
# Terrain de 300 mètres carrés…
#
# 						À vendre
#
# 						 17.000.000Fr
#
# Terrain de 225 mètres carrés à vendre à Saly Sénégal
# Terrain 225 mètres carrés à…
#
# 						À vendre
#
# 						 11.000.000Fr
#
# Terrain de 300 mètres carrés à vendre à Saly Sénégal
# Terrain de 300 mètres carrés…
#
# 						À vendre
#
# 						 27.000.000Fr
#
# Terrain de 300 mètres carrés à vendre à Saly Sénégal
# Terrain de 300 mètres carrés…
#
# 						À vendre
#
# 						 17.500.000Fr
#
# Terrain de 500 mètres carrés à vendre à Saly Sénégal
# Terrain de 500 mètres carrés…
#
# 						À vendre
#
# 						 35.000.000Fr
